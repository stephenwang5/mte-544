# %%
# %config InlineBackend.figure_formats = ["svg"]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("robotPose.csv")

data
# Out:
#                 t    imu_ax    imu_ay  odom_omega    odom_x    odom_y  \
# 0    1.700234e+09  0.021770 -0.010053    0.000006 -2.319675 -0.883773
# 1    1.700234e+09 -0.003694  0.004413    0.000005 -2.319675 -0.883773
# 2    1.700234e+09 -0.005838  0.002440   -0.000002 -2.319675 -0.883773
# 3    1.700234e+09  0.385941  0.205930   -0.000004 -2.319675 -0.883773
# 4    1.700234e+09  0.183298  0.007139    0.244746 -2.320009 -0.884035
# ..            ...       ...       ...         ...       ...       ...
# 96   1.700234e+09 -0.452060  0.341690    0.410166 -2.909151 -1.511142
# 97   1.700234e+09  0.260451  0.654007    0.428777 -2.886665 -1.544258
# 98   1.700234e+09 -0.033454  0.207446    0.430670 -2.863698 -1.575506
# 99   1.700234e+09 -0.020129 -0.063324    0.381530 -2.841141 -1.604156
# 100  1.700234e+09 -0.391839  0.224788    0.393233 -2.812032 -1.637727
#
#      odom_theta      kf_x      kf_y  kf_theta  kf_omega      kf_v   kf_vdot  \
# 0     -1.805351 -2.319663 -0.883720 -1.805351  0.000004  0.000271  0.016314
# 1     -1.805351 -2.319658 -0.883700 -1.805350  0.000005  0.000459  0.003569
# 2     -1.805351 -2.319664 -0.883725 -1.805350  0.000001  0.000207 -0.002275
# 3     -1.805351 -2.319557 -0.883279 -1.805348  0.000025  0.004097  0.237671
# 4     -1.792859 -2.319474 -0.882936 -1.795876  0.151301  0.014053  0.203857
# ..          ...       ...       ...       ...       ...       ...       ...
# 96    -1.009943 -3.029860 -1.509469  5.206085  0.438941  0.424017 -0.264937
# 97    -0.969384 -3.007348 -1.551274  5.254623  0.532006  0.513652  0.061562
# 98    -0.928211 -2.982746 -1.592079  5.304944  0.472302  0.442945  0.001513
# 99    -0.892345 -2.960138 -1.625715  5.347216  0.369213  0.357398 -0.013434
# 100   -0.850197 -2.937555 -1.656465  5.385349  0.397917  0.394500 -0.246405
#
#     Unnamed: 13
# 0
# 1
# 2
# 3
# 4
# ..          ...
# 96
# 97
# 98
# 99
# 100
#
# [101 rows x 14 columns]

# %%
import sys
for c in data.columns:
    setattr(sys.modules[__name__], c, data[c].to_numpy())

# %%
t -= t[0]

# %% [markdown]
# # Spiral

# %%
fig, axes = plt.subplots(3,2, figsize=(6,8))

fig.tight_layout(pad=4)

ax = axes[0,0]
ax.plot(t, imu_ay, label="imu")
ax.plot(t, kf_v * kf_omega, label="kf")
ax.legend()
ax.set_title(r"$a_y$")
ax.set_xlabel("t (s)")

ax = axes[0,1]
ax.plot(t, imu_ax, label="imu")
ax.plot(t, kf_vdot, label="kf")
ax.legend()
ax.set_title(r"$a_x$")
ax.set_xlabel("t (s)")

ax = axes[1,0]
ax.plot(t, odom_x, label="odom")
ax.plot(t, kf_x, label="kf")
ax.legend()
ax.set_title(r"$x$")
ax.set_xlabel("t (s)")

ax = axes[1,1]
ax.plot(t, odom_y, label="odom")
ax.plot(t, kf_y, label="kf")
ax.legend()
ax.set_title(r"$y$")
ax.set_xlabel("t (s)")

ax = axes[2,0]
ax.plot(t, odom_theta, label="odom")
ax.plot(t, kf_theta, label="kf")
ax.legend()
ax.set_title(r"$\theta$")
ax.set_xlabel("t (s)")

fig.show()
# Out:
# /tmp/ipykernel_113895/101148205.py:40: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # Line

# %%
fig, axes = plt.subplots(3,2, figsize=(6,8))

fig.tight_layout(pad=4)

ax = axes[0,0]
ax.plot(t, imu_ay, label="imu")
ax.plot(t, kf_v * kf_omega, label="kf")
ax.legend()
ax.set_title(r"$a_y$")
ax.set_xlabel("t (s)")

ax = axes[0,1]
ax.plot(t, imu_ax, label="imu")
ax.plot(t, kf_vdot, label="kf")
ax.legend()
ax.set_title(r"$a_x$")
ax.set_xlabel("t (s)")

ax = axes[1,0]
ax.plot(t, odom_x, label="odom")
ax.plot(t, kf_x, label="kf")
ax.legend()
ax.set_title(r"$x$")
ax.set_xlabel("t (s)")

ax = axes[1,1]
ax.plot(t, odom_y, label="odom")
ax.plot(t, kf_y, label="kf")
ax.legend()
ax.set_title(r"$y$")
ax.set_xlabel("t (s)")

ax = axes[2,0]
ax.plot(t, odom_theta, label="odom")
ax.plot(t, kf_theta, label="kf")
ax.legend()
ax.set_title(r"$\theta$")
ax.set_xlabel("t (s)")

ax = axes[2,1]
ax.plot(t, odom_omega, label="odom")
ax.plot(t, kf_omega, label="kf")
ax.legend()
ax.set_title(r"$\omega$")
ax.set_xlabel("t (s)")

fig.show()
# Out:
# /tmp/ipykernel_113895/584534886.py:47: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
diff = t[1:] - t[:-1]

# %%
diff.mean()
# Out:
# 0.1017939814602036

# %%
diff.std()
# Out:
# 0.013554228922513017

# %%
fig, axes = plt.subplots(2,2)

fig.tight_layout(pad=4)

ax = axes[0,0]
ax.plot(t, imu_ay, label="imu")
ax.plot(t, kf_v * kf_omega, label="kf")
ax.legend()
ax.set_title(r"$a_y$")
ax.set_xlabel("t (s)")

ax = axes[0,1]
ax.plot(t, imu_ax, label="imu")
ax.plot(t, kf_vdot, label="kf")
ax.legend()
ax.set_title(r"$a_x$")
ax.set_xlabel("t (s)")

ax = axes[1,0]
ax.plot(t, odom_x, label="odom")
ax.plot(t, kf_x, label="kf")
ax.legend()
ax.set_title(r"$x$")
ax.set_xlabel("t (s)")

ax = axes[1,1]
ax.plot(t, odom_y, label="odom")
ax.plot(t, kf_y, label="kf")
ax.legend()
ax.set_title(r"$y$")
ax.set_xlabel("t (s)")

fig.show()

# %%
fig, axes = plt.subplots(2,2)

fig.tight_layout(pad=4)

ax = axes[0,0]
ax.plot(t, imu_ay, label="imu")
ax.plot(t, kf_v * kf_omega, label="kf")
ax.legend()
ax.set_title(r"$a_y$")
ax.set_xlabel("t (s)")

ax = axes[0,1]
ax.plot(t, imu_ax, label="imu")
ax.plot(t, kf_vdot, label="kf")
ax.legend()
ax.set_title(r"$a_x$")
ax.set_xlabel("t (s)")

ax = axes[1,0]
ax.plot(t, odom_x, label="odom")
ax.plot(t, kf_x, label="kf")
ax.legend()
ax.set_title(r"$x$")
ax.set_xlabel("t (s)")

ax = axes[1,1]
ax.plot(t, odom_y, label="odom")
ax.plot(t, kf_y, label="kf")
ax.legend()
ax.set_title(r"$y$")
ax.set_xlabel("t (s)")

fig.show()

# %%
fig, axes = plt.subplots(2,2)

fig.tight_layout(pad=4)

ax = axes[0,0]
ax.plot(t, imu_ay, label="imu")
ax.plot(t, kf_v * kf_omega, label="kf")
ax.legend()
ax.set_title(r"$a_y$")
ax.set_xlabel("t (s)")

ax = axes[0,1]
ax.plot(t, imu_ax, label="imu")
ax.plot(t, kf_vdot, label="kf")
ax.legend()
ax.set_title(r"$a_x$")
ax.set_xlabel("t (s)")

ax = axes[1,0]
ax.plot(t, odom_x, label="odom")
ax.plot(t, kf_x, label="kf")
ax.legend()
ax.set_title(r"$x$")
ax.set_xlabel("t (s)")

ax = axes[1,1]
ax.plot(t, odom_y, label="odom")
ax.plot(t, kf_y, label="kf")
ax.legend()
ax.set_title(r"$y$")
ax.set_xlabel("t (s)")

fig.show()

# %%
fig, axes = plt.subplots(2,2)

fig.tight_layout(pad=4)

ax = axes[0,0]
ax.plot(t, imu_ay, label="imu")
ax.plot(t, kf_v * kf_omega, label="kf")
ax.legend()
ax.set_title(r"$a_y$")
ax.set_xlabel("t (s)")

ax = axes[0,1]
ax.plot(t, imu_ax, label="imu")
ax.plot(t, kf_vdot, label="kf")
ax.legend()
ax.set_title(r"$a_x$")
ax.set_xlabel("t (s)")

ax = axes[1,0]
ax.plot(t, odom_x, label="odom")
ax.plot(t, kf_x, label="kf")
ax.legend()
ax.set_title(r"$x$")
ax.set_xlabel("t (s)")

ax = axes[1,1]
ax.plot(t, odom_y, label="odom")
ax.plot(t, kf_y, label="kf")
ax.legend()
ax.set_title(r"$y$")
ax.set_xlabel("t (s)")

fig.show()
